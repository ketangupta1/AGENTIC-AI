# %% [markdown]
# Something cool - really showing you how "model inference" works via OpenAI

# %%
# %pip install matplotlib
# %pip install openai
# Out:
# Requirement already satisfied: matplotlib in /home/ketan/miniconda3/lib/python3.13/site-packages (3.11.1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/ketan/miniconda3/lib/python3.13/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/ketan/miniconda3/lib/python3.13/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in /home/ketan/miniconda3/lib/python3.13/site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/ketan/miniconda3/lib/python3.13/site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.25 in /home/ketan/miniconda3/lib/python3.13/site-packages (from matplotlib) (2.5.2)
# Requirement already satisfied: packaging>=20.0 in /home/ketan/miniconda3/lib/python3.13/site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=9 in /home/ketan/miniconda3/lib/python3.13/site-packages (from matplotlib) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in /home/ketan/miniconda3/lib/python3.13/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/ketan/miniconda3/lib/python3.13/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/ketan/miniconda3/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Collecting openai
#   Downloading openai-3.3.1-py3-none-any.whl.metadata (41 kB)
# Requirement already satisfied: anyio<5,>=4.10.0 in /home/ketan/miniconda3/lib/python3.13/site-packages (from openai) (4.12.1)
# Collecting httpx2<3,>=2.7.0 (from openai)
#   Downloading httpx2-2.12.0-py3-none-any.whl.metadata (9.5 kB)
# Collecting jiter<1,>=0.16.0 (from openai)
#   Downloading jiter-0.16.0-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.2 kB)
# Requirement already satisfied: pydantic!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,<3,>=1.10.13 in /home/ketan/miniconda3/lib/python3.13/site-packages (from openai) (2.13.2)
# Collecting sniffio (from openai)
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: typing-extensions<5,>=4.14 in /home/ketan/miniconda3/lib/python3.13/site-packages (from openai) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /home/ketan/miniconda3/lib/python3.13/site-packages (from anyio<5,>=4.10.0->openai) (3.11)
# Collecting httpcore2==2.12.0 (from httpx2<3,>=2.7.0->openai)
#   Downloading httpcore2-2.12.0-py3-none-any.whl.metadata (25 kB)
# Collecting idna>=2.8 (from anyio<5,>=4.10.0->openai)
#   Downloading idna-3.19-py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: truststore>=0.10 in /home/ketan/miniconda3/lib/python3.13/site-packages (from httpx2<3,>=2.7.0->openai) (0.10.1)
# Requirement already satisfied: h11>=0.16 in /home/ketan/miniconda3/lib/python3.13/site-packages (from httpcore2==2.12.0->httpx2<3,>=2.7.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/ketan/miniconda3/lib/python3.13/site-packages (from pydantic!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,<3,>=1.10.13->openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.46.2 in /home/ketan/miniconda3/lib/python3.13/site-packages (from pydantic!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,<3,>=1.10.13->openai) (2.46.2)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/ketan/miniconda3/lib/python3.13/site-packages (from pydantic!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,<3,>=1.10.13->openai) (0.4.2)
# Downloading openai-3.3.1-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 2.9 MB/s  0:00:00 eta 0:00:01
# Downloading httpx2-2.12.0-py3-none-any.whl (95 kB)
# Downloading httpcore2-2.12.0-py3-none-any.whl (83 kB)
# Downloading jiter-0.16.0-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (343 kB)
# Downloading idna-3.19-py3-none-any.whl (68 kB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Installing collected packages: sniffio, jiter, idna, httpcore2, httpx2, openai
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6 [openai]2m5/6 [openai]e2]
# Successfully installed httpcore2-2.12.0 httpx2-2.12.0 idna-3.19 jiter-0.16.0 openai-3.3.1 sniffio-1.3.1
# Note: you may need to restart the kernel to use updated packages.

# %%
from visualizer import TokenPredictor, create_token_graph, visualize_predictions

message = "In one sentence, describe the color orange to someone who has never been able to see"
model_name = "meta-llama/Llama-3.2-1B"

predictor = TokenPredictor(model_name)
predictions = predictor.predict_tokens(message)
G = create_token_graph(model_name, predictions)
plt = visualize_predictions(G)
plt.show()
